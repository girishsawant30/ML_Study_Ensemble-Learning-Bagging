# %%
import pandas as pd

df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df[df.RestingBP>(df.RestingBP.mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# ...

# %%
df[df.Cholesterol>(df.Cholesterol.mean()+3*df.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
df[df.MaxHR>(df.MaxHR.mean()+3*df.MaxHR.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df.Oldpeak>(df.Oldpeak.mean()+3*df.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 166    140              Y      5.0     Flat             1
# 702    145              N      4.2     Down             0
# 771    111              Y      5.6     Down             1
# 791    122              Y      4.2     Flat             1
# 850    145              N      6.2     Down             1
# 900    140              N      4.4     Down             1

# %%
df.shape
# Out:
# (918, 12)

# %%
df.HeartDisease.value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df.ST_Slope.value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
df_one_hot = pd.get_dummies(df, columns=['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'])

# %%
print("\nDataFrame after One-Hot Encoding:")
df_one_hot.head()
# Out:
# DataFrame after One-Hot Encoding:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP  ChestPainType_TA  \
# 0  False   True              False  ...              False             False
# 1   True  False              False  ...               True             False
# 2  False   True              False  ...              False             False
# 3   True  False               True  ...              False             False
# 4  False   True              False  ...               True             False
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
df['Sex_Label'] = label_encoder.fit_transform(df['Sex'])
df['ChestPainType_Label'] = label_encoder.fit_transform(df['ChestPainType'])
df['RestingECG_Label'] = label_encoder.fit_transform(df['RestingECG'])
df['ExerciseAngina_Label'] = label_encoder.fit_transform(df['ExerciseAngina'])
df['ST_Slope_Label'] = label_encoder.fit_transform(df['ST_Slope'])

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Sex_Label  \
# 0              N      0.0       Up             0          1
# 1              N      1.0     Flat             1          0
# 2              N      0.0       Up             0          1
# 3              Y      1.5     Flat             1          0
# 4              N      0.0       Up             0          1
#
#    ChestPainType_Label  RestingECG_Label  ExerciseAngina_Label  ST_Slope_Label
# ...

# %%
df.count()
# Out:
# Age                     918
# Sex                     918
# ChestPainType           918
# RestingBP               918
# Cholesterol             918
# FastingBS               918
# RestingECG              918
# MaxHR                   918
# ExerciseAngina          918
# Oldpeak                 918
# ST_Slope                918
# HeartDisease            918
# Sex_Label               918
# ChestPainType_Label     918
# RestingECG_Label        918
# ExerciseAngina_Label    918
# ST_Slope_Label          918
# dtype: int64

# %%
df1 = df.drop(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], axis='columns')

# %%
X = df1.drop("HeartDisease",axis='columns')
y = df1.HeartDisease

X.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_Label  \
# 0   40        140          289          0    172      0.0          1
# 1   49        160          180          0    156      1.0          0
# 2   37        130          283          0     98      0.0          1
# 3   48        138          214          0    108      1.5          0
# 4   54        150          195          0    122      0.0          1
#
#    ChestPainType_Label  RestingECG_Label  ExerciseAngina_Label  ST_Slope_Label
# 0                    1                 1                     0               2
# 1                    2                 1                     0               1
# 2                    1                 2                     0               2
# 3                    0                 1                     1               1
# 4                    2                 1                     0               2

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.4331398 ,  0.41090889,  0.82507026, ...,  0.01725451,
#         -0.8235563 ,  1.05211381],
#        [-0.47848359,  1.49175234, -0.17196105, ...,  0.01725451,
#         -0.8235563 , -0.59607813],
#        [-1.75135854, -0.12951283,  0.7701878 , ...,  1.60121899,
#         -0.8235563 ,  1.05211381],
#        ...,
#        [ 0.37009972, -0.12951283, -0.62016778, ...,  0.01725451,
#          1.21424608, -0.59607813],
#        [ 0.37009972, -0.12951283,  0.34027522, ..., -1.56670996,
#         -0.8235563 , -0.59607813],
#        [-1.64528563,  0.30282455, -0.21769643, ...,  0.01725451,
#         -0.8235563 ,  1.05211381]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=20)

# %%
X_train.shape
# Out:
# (734, 11)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

scores = cross_val_score(DecisionTreeClassifier(), X, y, cv=5)
scores
# Out:
# array([0.79347826, 0.73913043, 0.78804348, 0.75409836, 0.63934426])

# %%
scores.mean()
# Out:
# 0.7428189593727726

# %% [markdown]
# ***BY USING DECISION TREE***

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier


bag_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=100,
    max_samples=0.8,
    oob_score=True,
    random_state=0
)
bag_model.fit(X_train, y_train)
bag_model.oob_score_
# Out:
# 0.8542234332425068

# %% [markdown]
# ***BY USING RANDOM FOREST***

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier


bag_model = BaggingClassifier(
    estimator=RandomForestClassifier(),
    n_estimators=100,
    max_samples=0.8,
    oob_score=True,
    random_state=0
)

bag_model.fit(X_train, y_train)
bag_model.oob_score_
# Out:
# 0.8637602179836512
